# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class WaypointRacingEnv(gym.Env):
    """Advanced 2D Waypoint-Based Racing Track Environment"""
    metadata = {"render_modes": ["ansi"]}

    def __init__(self):
        super(WaypointRacingEnv, self).__init__()

        # 5 Discrete Actions: 0: Coast, 1: Left, 2: Right, 3: Accelerate, 4: Brake
        self.action_space = spaces.Discrete(5)

        # Observation Space: 5 Lidar rays + 1 velocity = 6 inputs
        self.observation_space = spaces.Box(
            low=0.0, high=30.0, shape=(6,), dtype=np.float32
        )

        # Define Track Centerline Waypoints (X, Y)
        # This creates a track that goes straight up, bends right, then bends left
        self.waypoints = np.array([
            [0.0, 0.0],
            [0.0, 40.0],    # Straight up
            [20.0, 60.0],   # Bend right-up
            [50.0, 60.0],   # Straight right
            [70.0, 80.0],   # Bend up-right
            [70.0, 120.0]   # Straight up to finish
        ], dtype=np.float32)

        self.TRACK_WIDTH = 12.0
        self.HALF_WIDTH = self.TRACK_WIDTH / 2.0  # 6.0 meters boundaries
        self.DT = 0.1
        self.MAX_SPEED = 10.0

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        # Spawn at the first waypoint facing straight up (pi/2)
        self.x = 0.0
        self.y = 0.0
        self.theta = np.pi / 2.0
        self.v = 0.0
        self.steps_taken = 0

        return self._get_obs(), {}

    def _is_inside_track(self, x, y):
        """Helper to determine if an (X,Y) point is within track boundaries"""
        # Find the shortest distance from the point to any track segment
        min_dist = float('inf')
        for i in range(len(self.waypoints) - 1):
            p1 = self.waypoints[i]
            p2 = self.waypoints[i+1]

            # Math vector projection to find distance from point to line segment
            segment_vec = p2 - p1
            point_vec = np.array([x, y]) - p1
            seg_len_sq = np.sum(segment_vec**2)

            if seg_len_sq == 0:
                dist = np.linalg.norm(point_vec)
            else:
                t = max(0.0, min(1.0, np.dot(point_vec, segment_vec) / seg_len_sq))
                projection = p1 + t * segment_vec
                dist = np.linalg.norm(np.array([x, y]) - projection)

            if dist < min_dist:
                min_dist = dist

        return min_dist <= self.HALF_WIDTH, min_dist

    def _get_obs(self):
        """Simulates 5 Lidar rays projecting forward to check boundaries"""
        ray_angles = [-np.pi/2, -np.pi/4, 0.0, np.pi/4, np.pi/2]
        distances = []

        for angle in ray_angles:
            global_angle = self.theta + angle
            found_wall = False

            # Cast out up to 30 meters to locate track edge
            for d in range(1, 31):
                check_x = self.x + d * np.cos(global_angle)
                check_y = self.y + d * np.sin(global_angle)

                inside, _ = self._is_inside_track(check_x, check_y)
                if not inside:
                    distances.append(float(d))
                    found_wall = True
                    break
            if not found_wall:
                distances.append(30.0)

        distances.append(self.v)
        return np.array(distances, dtype=np.float32)

    def step(self, action):
        self.steps_taken += 1

        # Process actions
        if action == 1:   self.theta += 0.15 # Stronger steering turn rate
        elif action == 2: self.theta -= 0.15
        elif action == 3: self.v = min(self.v + 0.5, self.MAX_SPEED)
        elif action == 4: self.v = max(self.v - 0.5, 0.0)

        # Kinematics Update
        self.x += self.v * np.cos(self.theta) * self.DT
        self.y += self.v * np.sin(self.theta) * self.DT

        # Check track constraints
        inside, distance_from_centerline = self._is_inside_track(self.x, self.y)

        # Terminal checks (crashed or completed the waypoint sequence)
        crashed = not inside
        reached_end = self.y >= 115.0  # Safe finish threshold near last waypoint
        timeout = self.steps_taken >= 400

        terminated = crashed or reached_end
        truncated = timeout

        # Structured reward function
        if crashed:
            reward = -200.0
        elif reached_end:
            reward = 500.0  # Massive success bonus for clean completion
        else:
            # Reward velocity while minimizing tracking offset errors
            reward = float(self.v) - (distance_from_centerline * 2.0)

        return self._get_obs(), reward, terminated, truncated, {}

# %%
# !pip install gymnasium stable-baselines3 shimmy --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 4.4 MB/s eta 0:00:00

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# 1. Instantiate our new waypoint track environment
bm_env = WaypointRacingEnv()

# 2. Define the training checkpoints
total_steps = 40000
eval_freq = 5000
steps_axis = list(range(eval_freq, total_steps + 1, eval_freq))

# TRAIN MODEL 1: Long-Term Planner (Gamma = 0.99)
print("--- Training Long-Term Planner (Gamma = 0.99) ---")
model_long = PPO("MlpPolicy", bm_env, verbose=0, learning_rate=0.0005, gamma=0.99)
rewards_long = []

for steps in steps_axis:
    model_long.learn(total_timesteps=eval_freq, reset_num_timesteps=False)
    mean_r, _ = evaluate_policy(model_long, bm_env, n_eval_episodes=3)
    rewards_long.append(mean_r)
    print(f"Steps: {steps} | Mean Evaluation Reward: {mean_r:.2f}")

# TRAIN MODEL 2: Short-Term Speedster (Gamma = 0.70)
print("\n--- Training Short-Term Speedster (Gamma = 0.70) ---")
model_short = PPO("MlpPolicy", bm_env, verbose=0, learning_rate=0.0005, gamma=0.70)
rewards_short = []

for steps in steps_axis:
    model_short.learn(total_timesteps=eval_freq, reset_num_timesteps=False)
    mean_r, _ = evaluate_policy(model_short, bm_env, n_eval_episodes=3)
    rewards_short.append(mean_r)
    print(f"Steps: {steps} | Mean Evaluation Reward: {mean_r:.2f}")

print("\nBenchmarking complete!")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# --- Training Long-Term Planner (Gamma = 0.99) ---
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Steps: 5000 | Mean Evaluation Reward: 1758.05
# Steps: 10000 | Mean Evaluation Reward: 1747.15
# Steps: 15000 | Mean Evaluation Reward: 1747.78
# Steps: 20000 | Mean Evaluation Reward: 1722.02
# Steps: 25000 | Mean Evaluation Reward: 1692.20
# Steps: 30000 | Mean Evaluation Reward: 1894.76
# Steps: 35000 | Mean Evaluation Reward: 1866.51
# Steps: 40000 | Mean Evaluation Reward: 1923.96
#
# --- Training Short-Term Speedster (Gamma = 0.70) ---
# Steps: 5000 | Mean Evaluation Reward: 459.42
# Steps: 10000 | Mean Evaluation Reward: 1564.44
# Steps: 15000 | Mean Evaluation Reward: 1903.45
# Steps: 20000 | Mean Evaluation Reward: 1753.97
# Steps: 25000 | Mean Evaluation Reward: 1963.79
# Steps: 30000 | Mean Evaluation Reward: 1969.59
# Steps: 35000 | Mean Evaluation Reward: 1986.04
# Steps: 40000 | Mean Evaluation Reward: 1982.63
#
# Benchmarking complete!

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot both datasets
plt.plot(steps_axis, rewards_long, marker='o', linestyle='-', color='b', linewidth=2, label='Long-Term Planner (Gamma=0.99)')
plt.plot(steps_axis, rewards_short, marker='s', linestyle='--', color='r', linewidth=2, label='Short-Term Speedster (Gamma=0.70)')

# Add formatting
plt.title('Hyperparameter Benchmark: Effect of Discount Factor (Gamma) on Track Completion', fontsize=12, fontweight='bold')
plt.xlabel('Training Timesteps', fontsize=10)
plt.ylabel('Mean Episode Evaluation Reward', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend(loc='lower right')

# Save and render
plt.savefig('hyperparameter_benchmark.png', dpi=300)
plt.show()

# %%
obs, info = bm_env.reset()
print("--- Testing the Final Short-Term Speedster Model ---")

for step in range(60):
    # Predict using the short-term model which yielded the highest mean reward
    action, _states = model_short.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = bm_env.step(action)

    # Extract coordinates directly from the environment to see the vehicle progress
    print(f"Step {step:02d} | Action: {action} | Pos: ({bm_env.x:.1f}, {bm_env.y:.1f}) | Velocity: {obs[5]:.1f} | Step Reward: {reward:.2f}")

    if terminated or truncated:
        print(f"--- Simulation Ended! Reason: {'Reached Finish Line!' if bm_env.y >= 115.0 else 'Crashed'} ---")
        break
# Out:
# --- Testing the Final Short-Term Speedster Model ---
# Step 00 | Action: 3 | Pos: (0.0, 0.1) | Velocity: 0.5 | Step Reward: 0.50
# Step 01 | Action: 3 | Pos: (0.0, 0.2) | Velocity: 1.0 | Step Reward: 1.00
# Step 02 | Action: 3 | Pos: (0.0, 0.3) | Velocity: 1.5 | Step Reward: 1.50
# Step 03 | Action: 3 | Pos: (0.0, 0.5) | Velocity: 2.0 | Step Reward: 2.00
# Step 04 | Action: 3 | Pos: (0.0, 0.8) | Velocity: 2.5 | Step Reward: 2.50
# Step 05 | Action: 3 | Pos: (0.0, 1.1) | Velocity: 3.0 | Step Reward: 3.00
# Step 06 | Action: 3 | Pos: (0.0, 1.4) | Velocity: 3.5 | Step Reward: 3.50
# Step 07 | Action: 3 | Pos: (0.0, 1.8) | Velocity: 4.0 | Step Reward: 4.00
# Step 08 | Action: 3 | Pos: (0.0, 2.3) | Velocity: 4.5 | Step Reward: 4.50
# Step 09 | Action: 3 | Pos: (0.0, 2.8) | Velocity: 5.0 | Step Reward: 5.00
# Step 10 | Action: 3 | Pos: (0.0, 3.3) | Velocity: 5.5 | Step Reward: 5.50
# Step 11 | Action: 3 | Pos: (0.0, 3.9) | Velocity: 6.0 | Step Reward: 6.00
# Step 12 | Action: 3 | Pos: (0.0, 4.6) | Velocity: 6.5 | Step Reward: 6.50
# Step 13 | Action: 3 | Pos: (0.0, 5.3) | Velocity: 7.0 | Step Reward: 7.00
# Step 14 | Action: 3 | Pos: (0.0, 6.0) | Velocity: 7.5 | Step Reward: 7.50
# Step 15 | Action: 3 | Pos: (0.0, 6.8) | Velocity: 8.0 | Step Reward: 8.00
# Step 16 | Action: 3 | Pos: (0.0, 7.7) | Velocity: 8.5 | Step Reward: 8.50
# Step 17 | Action: 3 | Pos: (0.0, 8.6) | Velocity: 9.0 | Step Reward: 9.00
# Step 18 | Action: 3 | Pos: (0.0, 9.5) | Velocity: 9.5 | Step Reward: 9.50
# Step 19 | Action: 3 | Pos: (0.0, 10.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 20 | Action: 3 | Pos: (0.0, 11.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 21 | Action: 3 | Pos: (0.0, 12.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 22 | Action: 3 | Pos: (0.0, 13.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 23 | Action: 3 | Pos: (0.0, 14.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 24 | Action: 3 | Pos: (0.0, 15.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 25 | Action: 3 | Pos: (0.0, 16.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 26 | Action: 3 | Pos: (0.0, 17.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 27 | Action: 3 | Pos: (0.0, 18.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 28 | Action: 3 | Pos: (0.0, 19.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 29 | Action: 3 | Pos: (0.0, 20.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 30 | Action: 3 | Pos: (0.0, 21.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 31 | Action: 3 | Pos: (0.0, 22.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 32 | Action: 3 | Pos: (0.0, 23.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 33 | Action: 3 | Pos: (0.0, 24.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 34 | Action: 3 | Pos: (0.0, 25.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 35 | Action: 3 | Pos: (0.0, 26.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 36 | Action: 3 | Pos: (0.0, 27.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 37 | Action: 3 | Pos: (0.0, 28.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 38 | Action: 3 | Pos: (0.0, 29.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 39 | Action: 3 | Pos: (0.0, 30.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 40 | Action: 3 | Pos: (0.0, 31.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 41 | Action: 3 | Pos: (0.0, 32.5) | Velocity: 10.0 | Step Reward: 10.00
# Step 42 | Action: 2 | Pos: (0.1, 33.5) | Velocity: 10.0 | Step Reward: 9.70
# Step 43 | Action: 3 | Pos: (0.3, 34.5) | Velocity: 10.0 | Step Reward: 9.40
# Step 44 | Action: 2 | Pos: (0.6, 35.4) | Velocity: 10.0 | Step Reward: 8.81
# Step 45 | Action: 1 | Pos: (0.7, 36.4) | Velocity: 10.0 | Step Reward: 8.51
# Step 46 | Action: 2 | Pos: (1.0, 37.4) | Velocity: 10.0 | Step Reward: 7.92
# Step 47 | Action: 2 | Pos: (1.5, 38.3) | Velocity: 10.0 | Step Reward: 7.05
# Step 48 | Action: 3 | Pos: (1.9, 39.2) | Velocity: 10.0 | Step Reward: 6.18
# Step 49 | Action: 3 | Pos: (2.3, 40.1) | Velocity: 10.0 | Step Reward: 6.80
# Step 50 | Action: 3 | Pos: (2.8, 41.0) | Velocity: 10.0 | Step Reward: 7.45
# Step 51 | Action: 3 | Pos: (3.2, 41.9) | Velocity: 10.0 | Step Reward: 8.11
# Step 52 | Action: 2 | Pos: (3.8, 42.7) | Velocity: 10.0 | Step Reward: 8.48
# Step 53 | Action: 3 | Pos: (4.3, 43.5) | Velocity: 10.0 | Step Reward: 8.85
# Step 54 | Action: 3 | Pos: (4.9, 44.4) | Velocity: 10.0 | Step Reward: 9.22
# Step 55 | Action: 3 | Pos: (5.5, 45.2) | Velocity: 10.0 | Step Reward: 9.59
# Step 56 | Action: 2 | Pos: (6.2, 45.9) | Velocity: 10.0 | Step Reward: 9.66
# Step 57 | Action: 3 | Pos: (6.8, 46.6) | Velocity: 10.0 | Step Reward: 9.73
# Step 58 | Action: 3 | Pos: (7.5, 47.4) | Velocity: 10.0 | Step Reward: 9.80
# Step 59 | Action: 3 | Pos: (8.2, 48.1) | Velocity: 10.0 | Step Reward: 9.87

# %%
import matplotlib.pyplot as plt
import numpy as np


waypoints = np.array([
    [0.0, 0.0],
    [0.0, 40.0],    # Straight up
    [20.0, 60.0],   # Bend right-up
    [50.0, 60.0],   # Straight right
    [70.0, 80.0],   # Bend up-right
    [70.0, 120.0]   # Straight up to finish
], dtype=np.float32)


obs, info = bm_env.reset()
car_x_coords = [bm_env.x]
car_y_coords = [bm_env.y]

for step in range(100):
    action, _states = model_short.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = bm_env.step(action)


    car_x_coords.append(bm_env.x)
    car_y_coords.append(bm_env.y)

    if terminated or truncated:
        break


plt.figure(figsize=(8, 10))

plt.plot(waypoints[:, 0], waypoints[:, 1], 'g--', label='Track Centerline (Waypoints)', alpha=0.6, linewidth=2)
plt.scatter(waypoints[:, 0], waypoints[:, 1], color='green', s=50, zorder=3, label='Waypoint Breadcrumbs')


plt.plot(car_x_coords, car_y_coords, color='blue', linestyle='-', linewidth=3, label='AI Driven Trajectory')
plt.scatter(car_x_coords[0], car_y_coords[0], color='cyan', marker='^', s=150, zorder=4, label='Start Position')
plt.scatter(car_x_coords[-1], car_y_coords[-1], color='magenta', marker='X', s=150, zorder=4, label='End/Crash Position')


plt.title('Autonomous Vehicle Trajectory Tracking Analysis', fontsize=12, fontweight='bold')
plt.xlabel('X Coordinate (Meters)', fontsize=10)
plt.ylabel('Y Coordinate (Meters)', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.5)
plt.axis('equal')
plt.legend(loc='lower right', fontsize=9)


plt.savefig('final_trajectory_plot.png', dpi=300)
plt.show()

# %% [markdown]
# _*UPDATED: adding an obstacle to my track_

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class ObstacleRacingEnv(gym.Env):

    metadata = {"render_modes": ["ansi"]}

    def __init__(self):
        super(ObstacleRacingEnv, self).__init__()
        self.action_space = spaces.Discrete(5)


        self.observation_space = spaces.Box(low=0.0, high=30.0, shape=(6,), dtype=np.float32)


        self.waypoints = np.array([
            [0.0, 0.0], [0.0, 40.0], [20.0, 60.0],
            [50.0, 60.0], [70.0, 80.0], [70.0, 120.0]
        ], dtype=np.float32)

        # Stalled car obstacle sitting directly on the centerline at (0, 25)
        self.obs_x, self.obs_y = 0.0, 25.0
        self.OBS_RADIUS = 2.5

        self.TRACK_WIDTH = 12.0
        self.HALF_WIDTH = self.TRACK_WIDTH / 2.0
        self.DT = 0.1
        self.MAX_SPEED = 10.0

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.x, self.y = 0.0, 0.0
        self.theta = np.pi / 2.0
        self.v = 0.0
        self.steps_taken = 0
        return self._get_obs(), {}

    def _is_inside_track(self, x, y):
        """Vector projection to check if coordinates are within track limits"""
        min_dist = float('inf')
        for i in range(len(self.waypoints) - 1):
            p1, p2 = self.waypoints[i], self.waypoints[i+1]
            segment_vec = p2 - p1
            point_vec = np.array([x, y]) - p1
            seg_len_sq = np.sum(segment_vec**2)

            if seg_len_sq == 0:
                dist = np.linalg.norm(point_vec)
            else:
                t = max(0.0, min(1.0, np.dot(point_vec, segment_vec) / seg_len_sq))
                projection = p1 + t * segment_vec
                dist = np.linalg.norm(np.array([x, y]) - projection)

            if dist < min_dist:
                min_dist = dist
        return min_dist <= self.HALF_WIDTH, min_dist

    def _get_obs(self):
        """Updated Lidar: Detects BOTH track borders and the obstacle"""
        ray_angles = [-np.pi/2, -np.pi/4, 0.0, np.pi/4, np.pi/2]
        distances = []

        for angle in ray_angles:
            global_angle = self.theta + angle
            found_collision = False


            for d in range(1, 31):
                check_x = self.x + d * np.cos(global_angle)
                check_y = self.y + d * np.sin(global_angle)

                # Check 1: Did the ray hit a wall
                inside, _ = self._is_inside_track(check_x, check_y)

                # Check 2: Did the ray hit our obstacle
                dist_to_obs = np.sqrt((check_x - self.obs_x)**2 + (check_y - self.obs_y)**2)

                if not inside or dist_to_obs <= self.OBS_RADIUS:
                    distances.append(float(d))
                    found_collision = True
                    break
            if not found_collision:
                distances.append(30.0)

        distances.append(self.v)
        return np.array(distances, dtype=np.float32)

    def step(self, action):
        self.steps_taken += 1

        # Core mechanics
        if action == 1:   self.theta += 0.2
        elif action == 2: self.theta -= 0.2
        elif action == 3: self.v = min(self.v + 0.5, self.MAX_SPEED)
        elif action == 4: self.v = max(self.v - 0.5, 0.0)

        self.x += self.v * np.cos(self.theta) * self.DT
        self.y += self.v * np.sin(self.theta) * self.DT

        inside, distance_from_centerline = self._is_inside_track(self.x, self.y)
        dist_to_obs = np.sqrt((self.x - self.obs_x)**2 + (self.y - self.obs_y)**2)


        crashed_wall = not inside
        crashed_obstacle = dist_to_obs <= 1.2
        reached_end = self.y >= 115.0

        terminated = crashed_wall or crashed_obstacle or reached_end
        truncated = self.steps_taken >= 400

        # The Repulsive Reward Calculation
        if crashed_wall or crashed_obstacle:
            reward = -300.0  # Higher penalty for failing completely
        elif reached_end:
            reward = 600.0   # Big bonus for crossing the line cleanly
        else:
            # Base progress reward
            reward = float(self.v) - (distance_from_centerline * 2.0)

            # Apply field penalty if inside the 6-meter warning zone
            if dist_to_obs < 6.0:
                reward -= (6.0 - dist_to_obs) * 5.0

        return self._get_obs(), reward, terminated, truncated, {}

# %%
# !pip install gymnasium stable-baselines3 shimmy --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 6.8 MB/s eta 0:00:00

# %%
from stable_baselines3 import PPO

print("Training the Obstacle Avoidance Model")


obs_env = ObstacleRacingEnv()


obs_model = PPO("MlpPolicy", obs_env, verbose=1, learning_rate=0.0005, gamma=0.70)


obs_model.learn(total_timesteps=50000)

print("\nTraining Complete!")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Training the Obstacle Avoidance Model
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -527     |
# | time/              |          |
# |    fps             | 129      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# ---------------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -550        |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 2           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015915524 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.00706     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 37.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 1.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -539        |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 3           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011520537 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 127         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -488        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 4           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013531093 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 647         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 1.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -398        |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 5           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012908794 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1e+03       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 6           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012920536 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 7           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012038294 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 13.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 1.83e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 8           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013961254 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 59.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 2.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 364         |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 9           |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008117284 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.56e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 2.9e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 567          |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 10           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0087303985 |
# |    clip_fraction        | 0.093        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 19.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 3.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 770         |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 11          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007419654 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 204         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0069     |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 138        |
# |    ep_rew_mean          | 950        |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 12         |
# |    time_elapsed         | 212        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00532165 |
# |    clip_fraction        | 0.0654     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.167      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 58         |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00533   |
# |    value_loss           | 2.98e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 13          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004850569 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 449         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 14           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0066897096 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.311        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 4.09e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 15          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005651909 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.3e+03     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 2.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 16          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004474731 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 732         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 2.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 1.1e+03     |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 17          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005224501 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.23e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 2.49e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 124          |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 18           |
# |    time_elapsed         | 320          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0043294383 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 2.19e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 2.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 19           |
# |    time_elapsed         | 337          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0057902355 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.96        |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 1.23e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00778     |
# |    value_loss           | 2.42e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 1.14e+03    |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 20          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014486342 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.49e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | 1.22e+03     |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 21           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0027145837 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 33.6         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 2.41e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 1.29e+03     |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 22           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0069453106 |
# |    clip_fraction        | 0.0953       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.348        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 98.3         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 2.52e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 1.37e+03    |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 23          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008514766 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 819         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 1.39e+03    |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 24          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013761928 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000549   |
# |    value_loss           | 2.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 1.54e+03    |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 25          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008539608 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 532         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 2.14e+03    |
# -----------------------------------------
#
# Training Complete!

# %%
import matplotlib.pyplot as plt


obs, info = obs_env.reset()
car_x_coords = [obs_env.x]
car_y_coords = [obs_env.y]


for step in range(120):
    action, _states = obs_model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = obs_env.step(action)


    car_x_coords.append(obs_env.x)
    car_y_coords.append(obs_env.y)

    if terminated or truncated:
        break


plt.figure(figsize=(8, 10))


plt.plot(obs_env.waypoints[:, 0], obs_env.waypoints[:, 1], 'g--', label='Track Centerline', alpha=0.5, linewidth=2)

# Render the Obstacle as a red circle indicating its field of influence
obstacle_circle = plt.Circle((obs_env.obs_x, obs_env.obs_y), obs_env.OBS_RADIUS, color='red', alpha=0.35, label='Stalled Car Obstacle')
plt.gca().add_patch(obstacle_circle)


plt.plot(car_x_coords, car_y_coords, color='darkblue', linewidth=3, label='AI Swerve Trajectory')
plt.scatter(car_x_coords[0], car_y_coords[0], color='cyan', marker='^', s=150, zorder=5, label='Start')
plt.scatter(car_x_coords[-1], car_y_coords[-1], color='magenta', marker='X', s=150, zorder=5, label='Finish')


plt.title('Dynamic Obstacle Avoidance & Trajectory Planning', fontsize=12, fontweight='bold')
plt.xlabel('X Coordinate (Meters)', fontsize=10)
plt.ylabel('Y Coordinate (Meters)', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.5)
plt.axis('equal')
plt.legend(loc='lower right', fontsize=9)


plt.savefig('obstacle_avoidance_plot.png', dpi=300)
plt.show()
